# %% [markdown]
# # DATASET CURATION - MASKED ROI PROJECT
#
#
# **Objectives**:
#
# To create the following groups:
# 1. **Positive group**: BIRADS 0 that became BIRADS 3, 4, 5, 6 in the subsequent diagnostic study
# 2. **Negative group**: BIRADS 1, 2 and BIRADS 0 that became BIRADS 1, 2 in the subsequent diagnostic study

# %% [markdown]
# ## 1. Prep

# %%
import pandas as pd
import numpy as np
import random
from tqdm import tqdm

from IPython.display import display

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)

# %%
def get_stats(df, suffix=None):
    """Provides a quick summary of a dataframe."""
    try:
        print(f"DF shape: {df.shape}")
        print(f"# Patients: {df.empi_anon.nunique()}")
        print(f"# Cases: {df.acc_anon.nunique()}\n")
        print(f"# Images: {df.png_path.nunique()}\n")
    except Exception as e:
        print(e)

# %%
# EMBED
metadata_full = pd.read_csv("/home/szelesteya/projects/EMBED_Open_Data/tables/EMBED_OpenData_metadata.csv", dtype=str)
magview_full = pd.read_csv("/home/szelesteya/projects/EMBED_Open_Data/tables/EMBED_OpenData_clinical.csv", dtype=str)

# %%
# Selecting the following columns

meta_cols = [
    "empi_anon",
    "acc_anon",
    "ImageLateralityFinal",
    "ViewPosition",
    "study_date_anon",
    "FinalImageType",
    "png_path",
    "StudyDescription",
    "match_level",
    "num_roi",
    "ROI_coords"
]

mag_cols = [
    "empi_anon",
    "acc_anon",
    "study_date_anon",
    "desc",
    "side",
    "asses",
    "path_severity",
    "bside",
    'procdate_anon',
    'pdate_anon',
]

# %%
metadata = metadata_full[meta_cols].copy()
magview = magview_full[mag_cols].copy()

# %%
metadata.study_date_anon = pd.to_datetime(metadata.study_date_anon)
magview.study_date_anon = pd.to_datetime(magview.study_date_anon)

# %%
metadata.num_roi = metadata.num_roi.astype(int)

# %% [markdown]
# ## 2. METADATA: 2D MLO & CC

# %%
# EMBED 2D (MLO and CC)
meta_2d = metadata.loc[(metadata.FinalImageType=="2D") & (metadata.ViewPosition.isin(["MLO", "CC"]))]
get_stats(meta_2d)
# Out:
# DF shape: (328961, 11)
# # Patients: 22455
# # Cases: 70861
#
# # Images: 328961

# %%
def get_image_stats(df):
    """Provides a quick summary of the number of unique images and the ROIs."""
    temp_df = pd.merge(df, meta_2d, on=["empi_anon", "acc_anon"], how="left")
    temp_df = temp_df.loc[
        (temp_df.side==temp_df.ImageLateralityFinal)
    ]
    temp_df.drop_duplicates(subset="png_path", inplace=True)
    print(f"# PNG PATH: {int(temp_df.png_path.nunique())}")
    print(f"# ROI: {int(temp_df.num_roi.sum())}")
    print(f"{temp_df.num_roi.value_counts()}")
    del temp_df

# %% [markdown]
# ## 3. Screening

# %%
# SCREENING
screening_magview = magview.loc[magview.desc.str.contains("screen", case=False)].copy()
get_stats(screening_magview)
# Out:
# DF shape: (58888, 10)
# # Patients: 20460
# # Cases: 55956
#
# 'DataFrame' object has no attribute 'png_path'

# %% [markdown]
# ### 3.1. Creating entries for the negative contralateral breast in bilateral examinations
#
# ```
# MAGVIEW only has entries if a finding exists.
#
# This means that if an exam is a bilateral exam and only one of the breast has a finding, the contralateral breast (negative) won't have an entry.
#
# This would be problematic at the time when we need to merge with METADATA, because the contralateral breast would be excluded.
#
# Therefore, we would need to create rows for the negative contralateral breast.
# ```

# %%
def get_exam_laterality(row):
    """A convenient function to get the exam laterality to be used with DF.apply() instead of iterating over each row."""
    if ("bilat" in row.desc.lower()):
        return "B"
    elif ("left" in row.desc.lower()):
        return "L"
    elif ("right" in row.desc.lower()):
        return "R"
    else:
        return None

# %%
# Applying the get_exam_laterality function
screening_magview["exam_laterality"] = screening_magview.apply(get_exam_laterality, axis=1)

# %%
screening_magview.exam_laterality.value_counts(dropna=False)
# Out:
# exam_laterality
# B    56558
# L     1180
# R     1150
# Name: count, dtype: int64

# %%
screening_magview.side.value_counts(dropna=False)
# Out:
# side
# NaN    39661
# L       8264
# R       8082
# B       2881
# Name: count, dtype: int64

# %%
# side == nan --> B
screening_magview.side = screening_magview.side.fillna("B")

# %%
# create copy for assigning B to R
screening_magview_r = screening_magview.loc[screening_magview.side=="B"].copy()
screening_magview_r.side = screening_magview.side.str.replace("B", "R")

# assigning B to L
screening_magview.side = screening_magview.side.str.replace("B", "L")

# appending R and L
screening_magview = pd.concat([screening_magview, screening_magview_r])

# %%
print(screening_magview.side.value_counts(dropna=False))
print(screening_magview.shape)
# Out:
# side
# L    50806
# R    50624
# Name: count, dtype: int64
# (101430, 11)

# %%
screening_magview = screening_magview.sort_values(["empi_anon", "acc_anon", "study_date_anon"]).drop_duplicates()
screening_magview
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 31489  10000879  6992096043050201      2018-02-16
# 31489  10000879  6992096043050201      2018-02-16
# 10198  10009146  4190527469809995      2014-07-04
# 10198  10009146  4190527469809995      2014-07-04
# 20474  10015693  1334581155737139      2015-10-11
# ...         ...               ...             ...
# 21119  99996622  9655172659462321      2016-06-04
# 25708  99999564  4369225803558884      2017-04-25
# 25708  99999564  4369225803558884      2017-04-25
# 31493  99999564  8832872399780580      2019-02-27
# 31493  99999564  8832872399780580      2019-02-27
#
#                                            desc side asses path_severity  \
# 31489  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 31489  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 10198  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 10198  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 20474  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     A           NaN
# ...                                         ...  ...   ...           ...
# 21119  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 25708  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 25708  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 31493  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 31493  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality
# 31489   NaN           NaN        NaN               B
# 31489   NaN           NaN        NaN               B
# 10198   NaN           NaN        NaN               B
# 10198   NaN           NaN        NaN               B
# 20474   NaN           NaN        NaN               B
# ...     ...           ...        ...             ...
# 21119   NaN           NaN        NaN               B
# 25708   NaN           NaN        NaN               B
# 25708   NaN           NaN        NaN               B
# 31493   NaN           NaN        NaN               B
# 31493   NaN           NaN        NaN               B
#
# [100120 rows x 11 columns]

# %%
exam_lat_b = screening_magview.loc[screening_magview.exam_laterality=="B"]
exam_lat_b.sample(2)
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 63065  92551711  5144930862304707      2017-10-08
# 77011  88606862  7861744225198264      2019-09-27
#
#                                            desc side asses path_severity  \
# 63065  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 77011  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality
# 63065   NaN           NaN        NaN               B
# 77011   NaN           NaN        NaN               B

# %%
# We want to aggregate all the sides for each bilateral exam so that we can filter those having only a single side.
exam_lat_b_agg = exam_lat_b.groupby('acc_anon')['side'].apply(''.join).reset_index()
exam_lat_b_agg.sample(2)
# Out:
#                acc_anon side
# 37217  7219285840077245    R
# 16661  3757998867335947   LR

# %%
exam_lat_b_agg.side.value_counts()
# Out:
# side
# LR        42769
# L          4938
# R          4882
# RL          615
# LL          123
# RR          114
# LLR          75
# LRR          43
# RLR          25
# LLRR         20
# RRL          16
# RLL          12
# LLL          11
# RLLR          5
# LRL           5
# RRR           4
# LRLR          4
# RRLL          3
# RRLR          2
# LLLRRR        2
# LRRR          1
# RRRR          1
# LLLLLR        1
# LLRRR         1
# LLLRR         1
# LLLR          1
# RRRLLL        1
# LRRL          1
# Name: count, dtype: int64

# %%
exam_lat_b_side_r = exam_lat_b_agg.loc[~(exam_lat_b_agg.side.str.contains("L"))].copy()
exam_lat_b_side_l = exam_lat_b_agg.loc[~(exam_lat_b_agg.side.str.contains("R"))].copy()

# %%
screening_magview_right_to_left = screening_magview.loc[screening_magview.acc_anon.isin(exam_lat_b_side_r.acc_anon)].copy().drop_duplicates()
screening_magview_left_to_right = screening_magview.loc[screening_magview.acc_anon.isin(exam_lat_b_side_l.acc_anon)].copy().drop_duplicates()

# %%
# Creating the negative Left side
screening_magview_right_to_left.loc[screening_magview_right_to_left.side=="R", "side"] = "L"
screening_magview_right_to_left.loc[screening_magview_right_to_left.side=="L", "asses"] = "N"
screening_magview_right_to_left.loc[screening_magview_right_to_left.side=="L", "path_severity"] = np.nan

screening_magview_right_to_left
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 37325  10033806  1069386741434572      2019-10-05
# 64534  10043985  1960584382049532      2018-04-18
# 59088  10043985  3613575521057039      2017-03-01
# 42847  10043985  9492972692582499      2014-05-14
# 8607   10065082  6346759651734606      2015-03-03
# ...         ...               ...             ...
# 11436  99853035  2905584160156737      2015-02-15
# 33776  99853035  6677454260490853      2019-02-07
# 67642  99860105  6470240272862407      2018-03-19
# 12820  99871644  5176060292067455      2015-06-26
# 73727  99935792  7342511220486189      2019-02-20
#
#                                            desc side asses path_severity  \
# 37325  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 64534  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 59088                    MG Screening Bilateral    L     N           NaN
# 42847                    MG Screening Bilateral    L     N           NaN
# 8607   MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# ...                                         ...  ...   ...           ...
# 11436  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 33776  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 67642  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
# 12820                    MG Screening Bilateral    L     N           NaN
# 73727  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality
# 37325   NaN           NaN        NaN               B
# 64534   NaN           NaN        NaN               B
# 59088   NaN           NaN        NaN               B
# 42847   NaN           NaN        NaN               B
# 8607    NaN           NaN        NaN               B
# ...     ...           ...        ...             ...
# 11436   NaN           NaN        NaN               B
# 33776   NaN           NaN        NaN               B
# 67642   NaN           NaN        NaN               B
# 12820   NaN           NaN        NaN               B
# 73727   NaN           NaN        NaN               B
#
# [5126 rows x 11 columns]

# %%
# Creating the negative Right side
screening_magview_left_to_right.loc[screening_magview_left_to_right.side=="L", "side"] = "R"
screening_magview_left_to_right.loc[screening_magview_left_to_right.side=="R", "asses"] = "N"
screening_magview_left_to_right.loc[screening_magview_left_to_right.side=="R", "path_severity"] = np.nan

screening_magview_left_to_right
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 20474  10015693  1334581155737139      2015-10-11
# 25070  10023113  5135241747022662      2016-10-05
# 63407  10029585  3189592535497441      2017-06-11
# 62320  10042753  1955284757719450      2017-06-15
# 37004  10044241  3993319361430024      2019-07-27
# ...         ...               ...             ...
# 80934  99881569  1140879824262422      2021-01-05
# 43901  99881569  3921887412575009      2013-11-02
# 9588   99908618  9288525074493489      2014-08-14
# 6519   99957941  2224428804635608      2014-06-03
# 29282  99986224  8107409307566891      2018-05-22
#
#                                            desc side asses path_severity  \
# 20474  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 25070  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 63407  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 62320  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 37004  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# ...                                         ...  ...   ...           ...
# 80934  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 43901              MG Screening Bilateral w/CAD    R     N           NaN
# 9588               MG Screening Bilateral w/CAD    R     N           NaN
# 6519                     MG Screening Bilateral    R     N           NaN
# 29282  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#       bside procdate_anon           pdate_anon exam_laterality
# 20474   NaN           NaN                  NaN               B
# 25070   NaN           NaN                  NaN               B
# 63407   NaN           NaN                  NaN               B
# 62320   NaN           NaN                  NaN               B
# 37004   NaN           NaN                  NaN               B
# ...     ...           ...                  ...             ...
# 80934   NaN           NaN                  NaN               B
# 43901   NaN           NaN                  NaN               B
# 9588      L    2014-08-26  2014-08-27 00:00:00               B
# 6519    NaN           NaN                  NaN               B
# 29282   NaN           NaN                  NaN               B
#
# [5217 rows x 11 columns]

# %%
# Merging the original and the two negative contralaterals
screening_magview_with_contralat = pd.concat([screening_magview, screening_magview_left_to_right, screening_magview_right_to_left]).sort_values(["empi_anon", "acc_anon", "study_date_anon"]).drop_duplicates()
screening_magview_with_contralat.sample(2)
# Out:
#       empi_anon          acc_anon study_date_anon  \
# 64187  95391222  2645893262086235      2017-04-11
# 18388  68630789  3761982580693787      2016-03-10
#
#                                            desc side asses path_severity  \
# 64187  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 18388  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L     N           NaN
#
#       bside procdate_anon pdate_anon exam_laterality
# 64187   NaN           NaN        NaN               B
# 18388   NaN           NaN        NaN               B

# %%
get_image_stats(screening_magview_with_contralat)
# Out:
# # PNG PATH: 258269
# # ROI: 5255
# num_roi
# 0.0    253498
# 1.0      4330
# 2.0       399
# 3.0        41
# 4.0         1
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2. BIRADS 0

# %%
b0 = screening_magview_with_contralat.loc[screening_magview_with_contralat.asses.isin(["A"])]

get_stats(b0)
get_image_stats(b0)
# Out:
# DF shape: (10876, 11)
# # Patients: 7747
# # Cases: 8829
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 24387
# # ROI: 5131
# num_roi
# 0.0    19725
# 1.0     4232
# 2.0      392
# 3.0       37
# 4.0        1
# Name: count, dtype: int64

# %% [markdown]
# ### 3.3. BIRADS 1, 2

# %%
b12 = screening_magview_with_contralat.loc[screening_magview_with_contralat.asses.isin(["B", "N"])]

get_stats(b12)
get_image_stats(b12)
# Out:
# DF shape: (99482, 11)
# # Patients: 19665
# # Cases: 54081
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 234362
# # ROI: 192
# num_roi
# 0.0    234192
# 1.0       153
# 2.0        12
# 3.0         5
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Diagnostic

# %%
diag_magview = magview.loc[magview.desc.str.contains('diag', case=False)]

get_stats(diag_magview)
print()
print(f"Asses Counts:\n{diag_magview.asses.value_counts()}")
# Out:
# DF shape: (22888, 10)
# # Patients: 9656
# # Cases: 16814
#
# 'DataFrame' object has no attribute 'png_path'
#
# Asses Counts:
# asses
# B    8794
# P    5563
# N    4193
# S    3063
# A     580
# K     386
# M     284
# X      25
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Screening BIRADS 0 and Diagnostic

# %%
b0_dx = pd.merge(b0, diag_magview, on='empi_anon', suffixes=[None, "_dx"])
b0_dx = b0_dx.loc[
    (b0_dx.side==b0_dx.side_dx)
    | (b0_dx.side_dx=="B")
    | (b0_dx.side_dx.isna())
]

# %%
# Getting only subsequent diagnostic studies within 3 months
b0_dx["delta_date_dx"] = (b0_dx.study_date_anon_dx - b0_dx.study_date_anon).dt.days
b0_dx_3mo = b0_dx.loc[b0_dx.delta_date_dx.isin(range(0, 91))]
b0_dx_3mo.sample(1)
# Out:
#       empi_anon          acc_anon study_date_anon                    desc  \
# 13888  70300497  4868622619390927      2015-12-07  MG Screening Bilateral
#
#       side asses path_severity bside procdate_anon pdate_anon exam_laterality  \
# 13888    R     A           NaN   NaN           NaN        NaN               B
#
#             acc_anon_dx study_date_anon_dx                        desc_dx  \
# 13888  5362144262639097         2016-02-11  MG Diagnostic Mammo Bilateral
#
#       side_dx asses_dx path_severity_dx bside_dx procdate_anon_dx  \
# 13888       R        B              NaN      NaN              NaN
#
#       pdate_anon_dx  delta_date_dx
# 13888           NaN             66

# %% [markdown]
# ### 5.1. BIRADS 0 (Screening) --> BIRADS 1, 2 (Diagnostic)

# %%
b0_12dx = b0_dx_3mo.loc[b0_dx_3mo.asses_dx.isin(["N", "B"])].copy()
get_stats(b0_12dx)
get_image_stats(b0_12dx)
# Out:
# DF shape: (3755, 21)
# # Patients: 2924
# # Cases: 3169
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 7695
# # ROI: 1676
# num_roi
# 0.0    6212
# 1.0    1306
# 2.0     162
# 3.0      14
# 4.0       1
# Name: count, dtype: int64

# %% [markdown]
# ### 5.2. BIRADS 0 (Screening) --> BIRADS 3, 4, 5, 6 (Diagnostic)

# %%
b0_3456dx = b0_dx_3mo.loc[b0_dx_3mo.asses_dx.isin(["P", "S", "M", "K"])].copy()
get_stats(b0_3456dx)
get_image_stats(b0_3456dx)
# Out:
# DF shape: (3491, 21)
# # Patients: 2100
# # Cases: 2187
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 5543
# # ROI: 1416
# num_roi
# 0.0    4268
# 1.0    1150
# 2.0     109
# 3.0      16
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Negative group

# %%
# Negative group = BIRADS_12 + BIRADS_0_12dx
neg_group = pd.concat([b12, b0_12dx])
neg_group.drop_duplicates(inplace=True)

get_stats(neg_group)
get_image_stats(neg_group)
# Out:
# DF shape: (103023, 21)
# # Patients: 19877
# # Cases: 54639
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 241885
# # ROI: 1860
# num_roi
# 0.0    240240
# 1.0      1451
# 2.0       174
# 3.0        19
# 4.0         1
# Name: count, dtype: int64

# %%
# Include only ones with negative follow-up after 1 year
neg_group_b12 = pd.merge(neg_group, b12, on=["empi_anon"], suffixes=(None, "_1yrfu"))

neg_group_b12 = neg_group_b12.loc[
    (neg_group_b12.side==neg_group_b12.side_1yrfu)
]

neg_group_b12["delta_date_1yrfu"] = (neg_group_b12.study_date_anon_1yrfu - neg_group_b12.study_date_anon).dt.days

get_stats(neg_group_b12)
get_image_stats(neg_group_b12)

neg_group_b12.sample(2)
# Out:
# DF shape: (419008, 32)
# # Patients: 19665
# # Cases: 54427
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 239895
# # ROI: 1287
# num_roi
# 0.0    238741
# 1.0      1034
# 2.0       108
# 3.0        11
# 4.0         1
# Name: count, dtype: int64
#        empi_anon          acc_anon study_date_anon  \
# 668586  82719304  9575884414073277      2016-01-19
# 775008  94630072  4186561795774382      2016-02-14
#
#                                             desc side asses path_severity  \
# 668586                    MG Screening Bilateral    R     N           NaN
# 775008  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
#
#        bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 668586   NaN           NaN        NaN               B         NaN
# 775008   NaN           NaN        NaN               B         NaN
#
#        study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 668586                NaT     NaN     NaN      NaN              NaN      NaN
# 775008                NaT     NaN     NaN      NaN              NaN      NaN
#
#        procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 668586              NaN           NaN            NaN  3954966127387819
# 775008              NaN           NaN            NaN  7378930085211253
#
#        study_date_anon_1yrfu                                desc_1yrfu  \
# 668586            2017-01-21  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 775008            2017-02-19  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#        side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 668586          R           N                 NaN         NaN
# 775008          R           N                 NaN         NaN
#
#        procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 668586                 NaN              NaN                     B
# 775008                 NaN              NaN                     B
#
#         delta_date_1yrfu
# 668586               368
# 775008               371

# %%
neg_group_1yrfu = neg_group_b12.loc[
    (neg_group_b12.delta_date_1yrfu > 360)
]
get_stats(neg_group_1yrfu)
get_image_stats(neg_group_1yrfu)
# Out:
# DF shape: (158091, 32)
# # Patients: 11590
# # Cases: 34180
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 150887
# # ROI: 690
# num_roi
# 0.0    150266
# 1.0       563
# 2.0        48
# 3.0         9
# 4.0         1
# Name: count, dtype: int64

# %%
neg_group_1yrfu_first_study = neg_group_1yrfu.sort_values(["empi_anon", "acc_anon", "study_date_anon_1yrfu"]).drop_duplicates(subset=["acc_anon", "side"]) # to only get the first followup study
get_stats(neg_group_1yrfu_first_study)
get_image_stats(neg_group_1yrfu_first_study)
# Out:
# DF shape: (63835, 32)
# # Patients: 11590
# # Cases: 34180
#
# 'DataFrame' object has no attribute 'png_path'
# # PNG PATH: 150887
# # ROI: 690
# num_roi
# 0.0    150266
# 1.0       563
# 2.0        48
# 3.0         9
# 4.0         1
# Name: count, dtype: int64

# %%
neg_group_1yrfu_first_study.path_severity.value_counts()
# Out:
# path_severity
# 4.0    25
# 2.0     7
# 0.0     4
# 3.0     1
# Name: count, dtype: int64

# %%
# Exclude any patient with any biopsy result
neg_group_1yrfu_first_study_no_biopsy = neg_group_1yrfu_first_study.loc[neg_group_1yrfu_first_study.path_severity.isna()].copy()

# %%
# Merging with METADATA to get the images
neg_group_1yrfu_first_study_no_biopsy_images = pd.merge(neg_group_1yrfu_first_study_no_biopsy, meta_2d, on=["empi_anon", "acc_anon", "study_date_anon"])
neg_group_1yrfu_first_study_no_biopsy_images = neg_group_1yrfu_first_study_no_biopsy_images.loc[
    (neg_group_1yrfu_first_study_no_biopsy_images.side == neg_group_1yrfu_first_study_no_biopsy_images.ImageLateralityFinal)
]
neg_group_1yrfu_first_study_no_biopsy_images.drop_duplicates(subset="png_path", inplace=True)
get_stats(neg_group_1yrfu_first_study_no_biopsy_images)
# Out:
# DF shape: (149727, 40)
# # Patients: 11243
# # Cases: 33180
#
# # Images: 149727

# %%
print(f"ROIs = {neg_group_1yrfu_first_study_no_biopsy_images.num_roi.sum()}")
print(neg_group_1yrfu_first_study_no_biopsy_images.num_roi.value_counts())
# Out:
# ROIs = 678
# num_roi
# 0    149116
# 1       555
# 2        46
# 3         9
# 4         1
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Positive Group

# %%
pos_group_images = pd.merge(b0_3456dx, meta_2d, on=["empi_anon", "acc_anon", "study_date_anon"])
pos_group_images = pos_group_images.loc[
    (pos_group_images.side == pos_group_images.ImageLateralityFinal)
]
pos_group_images.drop_duplicates(subset="png_path", inplace=True)
get_stats(pos_group_images)
# Out:
# DF shape: (5521, 29)
# # Patients: 2050
# # Cases: 2135
#
# # Images: 5521

# %%
print(f"ROIs  = {pos_group_images.num_roi.sum()}")
print(pos_group_images.num_roi.value_counts())
# Out:
# ROIs  = 1414
# num_roi
# 0    4248
# 1    1148
# 2     109
# 3      16
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Excluding Images from the Negative Group that are found in the Positive Group using acc_anon and side

# %%
# Merge negatives and positive groups
neg_pos = pd.merge(neg_group_1yrfu_first_study_no_biopsy_images, pos_group_images, on=["empi_anon", "acc_anon", "side"], suffixes=["_neg", "_pos"])
neg_pos.sample(2)
# Out:
#     empi_anon          acc_anon study_date_anon_neg  \
# 484  90739748  7155394177428117          2015-11-23
# 410  86343112  2369418586248410          2014-06-29
#
#                                      desc_neg side asses_neg  \
# 484  MG Screen Bilat w/Tomo/CAD Stnd Protocol    L         A
# 410  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R         A
#
#     path_severity_neg bside_neg procdate_anon_neg pdate_anon_neg  \
# 484               NaN       NaN               NaN            NaN
# 410               NaN       NaN               NaN            NaN
#
#     exam_laterality_neg   acc_anon_dx_neg study_date_anon_dx_neg  \
# 484                   B  8225301671906659             2015-12-09
# 410                   B  7394215681214742             2014-07-03
#
#                               desc_dx_neg side_dx_neg asses_dx_neg  \
# 484              MG Diagnostic Left w/CAD           L            N
# 410  MG Diagnostic  Right w/Tomosynthesis           R            N
#
#     path_severity_dx_neg bside_dx_neg procdate_anon_dx_neg pdate_anon_dx_neg  \
# 484                  NaN          NaN                  NaN               NaN
# 410                  NaN          NaN                  NaN               NaN
#
#      delta_date_dx_neg    acc_anon_1yrfu study_date_anon_1yrfu  \
# 484               16.0  6279142675661006            2019-10-21
# 410                4.0  8490502153918576            2016-10-08
#
#                                    desc_1yrfu side_1yrfu asses_1yrfu  \
# 484  MG Screen Bilat w/Tomo/CAD Stnd Protocol          L           N
# 410  MG Screen Bilat w/Tomo/CAD Stnd Protocol          R           N
#
#     path_severity_1yrfu bside_1yrfu procdate_anon_1yrfu pdate_anon_1yrfu  \
# 484                 NaN         NaN                 NaN              NaN
# 410                 NaN         NaN                 NaN              NaN
#
#     exam_laterality_1yrfu  delta_date_1yrfu ImageLateralityFinal_neg  \
# 484                     B              1428                        L
# 410                     B               832                        R
#
#     ViewPosition_neg FinalImageType_neg  \
# 484              MLO                 2D
# 410               CC                 2D
#
#                                           png_path_neg  \
# 484  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 410  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
#
#                          StudyDescription_neg match_level_neg  num_roi_neg  \
# 484  MG Screen Bilat w/Tomo/CAD Stnd Protocol             [1]            1
# 410  MG Screen Bilat w/Tomo/CAD Stnd Protocol              []            0
#
#                 ROI_coords_neg study_date_anon_pos  \
# 484  ((1752, 623, 1983, 985),)          2015-11-23
# 410                         ()          2014-06-29
#
#                                      desc_pos asses_pos path_severity_pos  \
# 484  MG Screen Bilat w/Tomo/CAD Stnd Protocol         A               NaN
# 410  MG Screen Bilat w/Tomo/CAD Stnd Protocol         A               NaN
#
#     bside_pos procdate_anon_pos pdate_anon_pos exam_laterality_pos  \
# 484       NaN               NaN            NaN                   B
# 410       NaN               NaN            NaN                   B
#
#       acc_anon_dx_pos study_date_anon_dx_pos  \
# 484  8225301671906659             2015-12-09
# 410  7394215681214742             2014-07-03
#
#                               desc_dx_pos side_dx_pos asses_dx_pos  \
# 484              MG Diagnostic Left w/CAD           L            P
# 410  MG Diagnostic  Right w/Tomosynthesis           R            P
#
#     path_severity_dx_pos bside_dx_pos procdate_anon_dx_pos pdate_anon_dx_pos  \
# 484                  NaN          NaN                  NaN               NaN
# 410                  NaN          NaN                  NaN               NaN
#
#      delta_date_dx_pos ImageLateralityFinal_pos ViewPosition_pos  \
# 484                 16                        L              MLO
# 410                  4                        R               CC
#
#     FinalImageType_pos                                       png_path_pos  \
# 484                 2D  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 410                 2D  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
#
#                          StudyDescription_pos match_level_pos  num_roi_pos  \
# 484  MG Screen Bilat w/Tomo/CAD Stnd Protocol             [1]            1
# 410  MG Screen Bilat w/Tomo/CAD Stnd Protocol              []            0
#
#                 ROI_coords_pos
# 484  ((1752, 623, 1983, 985),)
# 410                         ()

# %%
# Create new KeyID of acc_anon + side on negative group and negative+positive group
neg_pos["acc_anon_side"] = neg_pos.acc_anon + neg_pos.side
neg_pos.sample(2)
# Out:
#     empi_anon          acc_anon study_date_anon_neg  \
# 75   23403355  2178194762485773          2013-11-15
# 284  69943636  9006977453526071          2013-11-09
#
#                          desc_neg side asses_neg path_severity_neg bside_neg  \
# 75   MG Screening Bilateral w/CAD    L         B               NaN       NaN
# 284  MG Screening Bilateral w/CAD    L         A               NaN       NaN
#
#     procdate_anon_neg pdate_anon_neg exam_laterality_neg   acc_anon_dx_neg  \
# 75                NaN            NaN                   B               NaN
# 284               NaN            NaN                   B  1753412361881724
#
#     study_date_anon_dx_neg                              desc_dx_neg  \
# 75                     NaT                                      NaN
# 284             2013-11-23  MG Diagnostic Bilateral w/Tomosynthesis
#
#     side_dx_neg asses_dx_neg path_severity_dx_neg bside_dx_neg  \
# 75          NaN          NaN                  NaN          NaN
# 284           L            B                  NaN          NaN
#
#     procdate_anon_dx_neg pdate_anon_dx_neg  delta_date_dx_neg  \
# 75                   NaN               NaN                NaN
# 284                  NaN               NaN               14.0
#
#        acc_anon_1yrfu study_date_anon_1yrfu  \
# 75   5145328297721299            2015-01-02
# 284  9653903342984476            2019-10-10
#
#                                    desc_1yrfu side_1yrfu asses_1yrfu  \
# 75   MG Screen Bilat w/Tomo/CAD Stnd Protocol          L           N
# 284  MG Screen Bilat w/Tomo/CAD Stnd Protocol          L           N
#
#     path_severity_1yrfu bside_1yrfu procdate_anon_1yrfu pdate_anon_1yrfu  \
# 75                  NaN         NaN                 NaN              NaN
# 284                 NaN         NaN                 NaN              NaN
#
#     exam_laterality_1yrfu  delta_date_1yrfu ImageLateralityFinal_neg  \
# 75                      B               413                        L
# 284                     B              2161                        L
#
#     ViewPosition_neg FinalImageType_neg  \
# 75               MLO                 2D
# 284               CC                 2D
#
#                                           png_path_neg  \
# 75   /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 284  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
#
#              StudyDescription_neg match_level_neg  num_roi_neg ROI_coords_neg  \
# 75   MG Screening Bilateral w/CAD              []            0             ()
# 284  MG Screening Bilateral w/CAD              []            0             ()
#
#     study_date_anon_pos                      desc_pos asses_pos  \
# 75           2013-11-15  MG Screening Bilateral w/CAD         A
# 284          2013-11-09  MG Screening Bilateral w/CAD         A
#
#     path_severity_pos bside_pos procdate_anon_pos pdate_anon_pos  \
# 75                NaN       NaN               NaN            NaN
# 284               NaN       NaN               NaN            NaN
#
#     exam_laterality_pos   acc_anon_dx_pos study_date_anon_dx_pos  \
# 75                    B  3539141438628064             2013-11-29
# 284                   B  1753412361881724             2013-11-23
#
#                                  desc_dx_pos side_dx_pos asses_dx_pos  \
# 75                        MG Diagnostic Left           L            S
# 284  MG Diagnostic Bilateral w/Tomosynthesis           L            P
#
#     path_severity_dx_pos bside_dx_pos procdate_anon_dx_pos  \
# 75                   4.0            L           2013-12-14
# 284                  NaN          NaN                  NaN
#
#        pdate_anon_dx_pos  delta_date_dx_pos ImageLateralityFinal_pos  \
# 75   2013-12-18 00:00:00                 14                        L
# 284                  NaN                 14                        L
#
#     ViewPosition_pos FinalImageType_pos  \
# 75               MLO                 2D
# 284              MLO                 2D
#
#                                           png_path_pos  \
# 75   /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 284  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
#
#              StudyDescription_pos match_level_pos  num_roi_pos ROI_coords_pos  \
# 75   MG Screening Bilateral w/CAD              []            0             ()
# 284  MG Screening Bilateral w/CAD              []            0             ()
#
#          acc_anon_side
# 75   2178194762485773L
# 284  9006977453526071L

# %%
neg_group_1yrfu_first_study_no_biopsy_images["acc_anon_side"] = neg_group_1yrfu_first_study_no_biopsy_images.acc_anon + neg_group_1yrfu_first_study_no_biopsy_images.side
neg_group_1yrfu_first_study_no_biopsy_images.sample(2)
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 2849    10908410  8705088827027165      2017-05-24
# 268612  91746780  5521629479489499      2016-09-08
#
#                                             desc side asses path_severity  \
# 2849    MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 268612                    MG Screening Bilateral    L     N           NaN
#
#        bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 2849     NaN           NaN        NaN               B         NaN
# 268612   NaN           NaN        NaN               B         NaN
#
#        study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 2849                  NaT     NaN     NaN      NaN              NaN      NaN
# 268612                NaT     NaN     NaN      NaN              NaN      NaN
#
#        procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 2849                NaN           NaN            NaN  4104556289608579
# 268612              NaN           NaN            NaN  7461032943488451
#
#        study_date_anon_1yrfu                                desc_1yrfu  \
# 2849              2018-06-06  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 268612            2017-09-15  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#        side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 2849            R           N                 NaN         NaN
# 268612          L           N                 NaN         NaN
#
#        procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 2849                   NaN              NaN                     B
# 268612                 NaN              NaN                     B
#
#         delta_date_1yrfu ImageLateralityFinal ViewPosition FinalImageType  \
# 2849                 378                    R          MLO             2D
# 268612               372                    L          MLO             2D
#
#                                                  png_path  \
# 2849    /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
# 268612  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
#
#                                 StudyDescription match_level  num_roi  \
# 2849    MG Screen Bilat w/Tomo/CAD Stnd Protocol          []        0
# 268612                    MG Screening Bilateral          []        0
#
#        ROI_coords      acc_anon_side
# 2849           ()  8705088827027165R
# 268612         ()  5521629479489499L

# %%
# Removing any images that are found in the positive group from the negative group using the created KeyID (acc_anon+side)
neg_group_final = neg_group_1yrfu_first_study_no_biopsy_images.loc[~neg_group_1yrfu_first_study_no_biopsy_images.acc_anon_side.isin(neg_pos.acc_anon_side)]
neg_group_final.sample(2)
# Out:
#        empi_anon          acc_anon study_date_anon  \
# 144673  54158646  4724842923697642      2018-07-18
# 155457  57120502  9590770378094025      2013-11-04
#
#                                             desc side asses path_severity  \
# 144673  MG Screen Bilat w/Tomo/CAD Stnd Protocol    R     N           NaN
# 155457              MG Screening Bilateral w/CAD    R     N           NaN
#
#        bside procdate_anon pdate_anon exam_laterality acc_anon_dx  \
# 144673   NaN           NaN        NaN               B         NaN
# 155457   NaN           NaN        NaN               B         NaN
#
#        study_date_anon_dx desc_dx side_dx asses_dx path_severity_dx bside_dx  \
# 144673                NaT     NaN     NaN      NaN              NaN      NaN
# 155457                NaT     NaN     NaN      NaN              NaN      NaN
#
#        procdate_anon_dx pdate_anon_dx  delta_date_dx    acc_anon_1yrfu  \
# 144673              NaN           NaN            NaN  9458387876781172
# 155457              NaN           NaN            NaN  2295083017858248
#
#        study_date_anon_1yrfu                                desc_1yrfu  \
# 144673            2019-12-26  MG Screen Bilat w/Tomo/CAD Stnd Protocol
# 155457            2014-12-22  MG Screen Bilat w/Tomo/CAD Stnd Protocol
#
#        side_1yrfu asses_1yrfu path_severity_1yrfu bside_1yrfu  \
# 144673          R           N                 NaN         NaN
# 155457          R           N                 NaN         NaN
#
#        procdate_anon_1yrfu pdate_anon_1yrfu exam_laterality_1yrfu  \
# 144673                 NaN              NaN                     B
# 155457                 NaN              NaN                     B
#
#         delta_date_1yrfu ImageLateralityFinal ViewPosition FinalImageType  \
# 144673               526                    R           CC             2D
# 155457               413                    R          MLO             2D
#
#                                                  png_path  \
# 144673  /mnt/PACS_NAS1/mammo/png/cohort_2/extracted-im...
# 155457  /mnt/PACS_NAS1/mammo/png/cohort_1/extracted-im...
#
#                                 StudyDescription match_level  num_roi  \
# 144673  MG Screen Bilat w/Tomo/CAD Stnd Protocol          []        0
# 155457              MG Screening Bilateral w/CAD          []        0
#
#        ROI_coords      acc_anon_side
# 144673         ()  4724842923697642R
# 155457         ()  9590770378094025R

# %%
get_stats(neg_group_final)

print(f"ROIs  = {neg_group_final.num_roi.sum()}")
print(neg_group_final.num_roi.value_counts())
# Out:
# DF shape: (149523, 41)
# # Patients: 11238
# # Cases: 33162
#
# # Images: 149523
#
# ROIs  = 644
# num_roi
# 0    148940
# 1       532
# 2        42
# 3         8
# 4         1
# Name: count, dtype: int64

# %% [markdown]
# ## 9. Saving and Exporting

# %%
columns_to_save = [
    'empi_anon',
    'acc_anon',
    'desc',
    'asses',
    'asses_dx',
    'path_severity',
    'study_date_anon',
    'study_date_anon_dx',
    'side',
    'ImageLateralityFinal',
    'bside',
    'ViewPosition',
    'match_level',
    'num_roi',
    'ROI_coords',
    'png_path',
]

# %%
neg_group_final[columns_to_save].to_csv("NEGATIVE_GROUP.csv", index=False)

# %%
pos_group_images[columns_to_save].to_csv("POSITIVE_GROUP.csv", index=False)

# %% [markdown]
# # END
