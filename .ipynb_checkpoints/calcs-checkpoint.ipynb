# %% [markdown]
# # Positive samples for the dataset

# %% [markdown]
# ## Extracting relevant information from the dataset

# %%
import pandas as pd
import numpy as np
import pydicom
import png
import math
from PIL import Image
from pathlib import Path
import boto3
import matplotlib.pyplot as plt
from collections import Counter

data_path = '/home/szelesteya/projects/EMBED_Open_Data/'
tables_path = data_path + 'tables/'
image_root_path = '/media/szelesteya/F824D4D024D492CC/EMBED-images/'
image_dcm_path = image_root_path + 'dicom-positive/'
image_png_path = image_root_path + 'positive-full'

# %%
# Import Legends which describe clinical information's labeling
df_legends = pd.read_csv(tables_path + 'AWS_Open_Data_Clinical_Legend.csv')

# Keep relevant information that is about calcifications
df_calcs = df_legends[df_legends['Header in export'].isin(['calcfind'])][['Code',
                                                                          'Meaning']]

# Drop codes that are irrelevant
df_calcs_rel = df_calcs[~df_calcs['Code'].isin(['V','U','S','M'])]

# df_calcs_rel

# %%
cli_df = pd.read_csv(tables_path + 'EMBED_OpenData_clinical.csv', low_memory=False)

# Only keeping result BIRADS-1 and BIRADS-2 screenings
pos_cli_df = cli_df[((cli_df.calcfind.notna()) & 
                     (cli_df.calcfind.isin(df_calcs_rel['Code'])))][[  'Unnamed: 0',
                                                                       'empi_anon',
                                                                       'acc_anon',
                                                                       'side',
                                                                       'calcfind',
                                                                       'calcdistri',
                                                                       'otherfind',
                                                                       'numfind',
                                                                       'path_severity',
                                                                       'age_at_study',
                                                                       'ETHNICITY_DESC',
                                                                       'study_date_anon',
                                                                       'asses']]

# Rename columns to prepare for merge
pos_cli_df = pos_cli_df.rename(columns={'study_date_anon':'diag_study_date'})

# %%
# Reading image metadata
meta_df = (pd.read_csv(tables_path + 'EMBED_OpenData_metadata_reduced.csv', low_memory=False))
meta_red_df = meta_df[  (meta_df['ROI_coords'] != "()") &
                        (meta_df['FinalImageType'] == '2D') &                         
                        (meta_df['spot_mag'] != 1)][[  'empi_anon',
                                                                'acc_anon',
                                                                'ImageLateralityFinal',
                                                                'anon_dicom_path',
                                                                'study_date_anon',
                                                                'ViewPosition', 
                                                                'num_roi',
                                                                'ROI_coords',
                                                                'spot_mag']]

# Rename columns to prepare for merge
meta_red_ren_df = meta_red_df.rename(columns={'ImageLateralityFinal':'side'})

# %%
# Merging clinical information with medical ones
pos_full_df = pos_cli_df.merge(meta_red_ren_df, on=['empi_anon','acc_anon','side'])

# Generate paths for png extraction
pos_full_df['relative_dcm_path'] = pos_full_df['anon_dicom_path'].apply(lambda x: '/'.join(x.split('/')[5:]))

# Keeping relevant columns
pos_empi_df = pos_full_df[['empi_anon',
                           'acc_anon',
                           'side',
                           'asses',
                           'age_at_study',
                           'calcfind',
                           'calcdistri',
                           'otherfind',
                           'numfind',
                           'ViewPosition',
                           'num_roi',
                           'ROI_coords',
                           'ETHNICITY_DESC',
                           'study_date_anon',
                           'diag_study_date',
                           'relative_dcm_path',
                           'spot_mag']]

# Rename columns to be more consistent
pos_empi_df = pos_empi_df.rename(columns={'ETHNICITY_DESC':'eth_desc',
                                          'calcfind':'calc_find',
                                          'calcdistri':'calc_distrib',
                                          'otherfind':'other_find',                                          
                                          'ViewPosition':'view_pos',
                                          'numfind':'num_find'})


# Convert study date so it is easily interpreted by Python
pos_empi_df['diag_study_date'] = pd.to_datetime(pos_empi_df['diag_study_date'], errors='coerce', format= '%Y-%m-%d')
pos_empi_df['study_date_anon'] = pd.to_datetime(pos_empi_df['study_date_anon'], errors='coerce')

# Keeping only screening exams with less than 180 day differential between diagnosis date and last exam date (the diagnosis might be outdated on other circumstances)
pos_empi_df['diag_date_diff'] = pos_empi_df.diag_study_date - pos_empi_df.study_date_anon
pos_empi_rel_df= pos_empi_df.loc[(pos_empi_df.diag_date_diff.dt.days >= 0) & 
                                 (pos_empi_df.diag_date_diff.dt.days <= 180)]

# %%
bins = plt.hist(pos_empi_rel_df['calc_find'])
counts = Counter(pos_empi_rel_df['calc_find'])
# plt.text([(i + 0.5) for i in range(len(counts.values()))], str(counts.values()))
plt.savefig('calc_types')
plt.show()
counts
# Out:
# Counter({'G': 1142,
#          'A': 56,
#          'P': 27,
#          'H': 25,
#          'K': 22,
#          'Q': 13,
#          'R': 7,
#          'I': 6,
#          'D': 6,
#          'F': 2})

# %%
with open(data_path + 'positive_empirical.csv', 'w') as f:
    pos_empi_rel_df.to_csv(f)

# %% [markdown]
# ## Pulling the DICOM images with a bash script

# %%
# Printing the path to file to read it in the bash script
with open(data_path + 'positive_path.csv', 'w') as f:
    pos_empi_rel_df.drop_duplicates(subset=['relative_dcm_path'])['relative_dcm_path'].to_csv(f, index=False)

# %%
# %%bash -s "$image_dcm_path" "{data_path}positive_path.csv"
#
# # Pulling dicom files with AWS CLI (Python API didn't work)
# dcm_dest_path="$1"
# dcm_paths="$2"
# ind=$((1))
#
# tail -n +2 $dcm_paths | while IFS= read -r line; do
#     relative_path=$(echo "$line" | awk -v OFS='/' '{$1=$1; print}')
#     dcm_name=$(echo "$relative_path" | cut -d '/' -f 3-)
#
#     file="${dcm_dest_path}$relative_path"
#     dir=$(dirname $file)
#     mkdir $dir -p
#     echo "$ind / 146"
#
#     if [ -f "$file" ]; then
#         echo "File already present"
#     else
#         if [ -f "${dcm_dest_path}$dcm_name" ]; then
#             dcm="${dcm_dest_path}$dcm_name"
#             dir_dcm=$(dirname $dcm)
#             echo "Moving file from ${dir_dcm}"
#             mv "${dcm}" "${dcm_dest_path}$relative_path"
#         else
#             echo "Pulling file $file"
#             aws s3 cp "s3://embed-dataset-open/images/$relative_path" "${file}" --profile my-dev-profile
#         fi
#     fi
#
#
#     ind=$((ind+1))
#     clear
# done
# Out:
# 1 / 146
# File already present
# 2 / 146
# File already present
# 3 / 146
# File already present
# 4 / 146
# File already present
# 5 / 146
# File already present
# 6 / 146
# File already present
# 7 / 146
# File already present
# 8 / 146
# File already present
# 9 / 146
# File already present
# 10 / 146
# File already present
# 11 / 146
# File already present
# 12 / 146
# File already present
# 13 / 146
# File already present
# 14 / 146
# File already present
# 15 / 146
# File already present
# 16 / 146
# File already present
# 17 / 146
# File already present
# 18 / 146
# File already present
# 19 / 146
# File already present
# 20 / 146
# File already present
# 21 / 146
# File already present
# 22 / 146
# File already present
# 23 / 146
# File already present
# 24 / 146
# File already present
# 25 / 146
# File already present
# 26 / 146
# File already present
# 27 / 146
# File already present
# 28 / 146
# File already present
# 29 / 146
# File already present
# 30 / 146
# File already present
# 31 / 146
# File already present
# 32 / 146
# File already present
# 33 / 146
# File already present
# 34 / 146
# File already present
# 35 / 146
# File already present
# 36 / 146
# File already present
# 37 / 146
# File already present
# 38 / 146
# File already present
# 39 / 146
# File already present
# 40 / 146
# File already present
# 41 / 146
# File already present
# 42 / 146
# File already present
# 43 / 146
# File already present
# 44 / 146
# File already present
# 45 / 146
# File already present
# 46 / 146
# File already present
# 47 / 146
# File already present
# 48 / 146
# File already present
# 49 / 146
# File already present
# 50 / 146
# File already present
# 51 / 146
# File already present
# 52 / 146
# File already present
# 53 / 146
# File already present
# 54 / 146
# File already present
# 55 / 146
# File already present
# 56 / 146
# File already present
# 57 / 146
# File already present
# 58 / 146
# File already present
# 59 / 146
# File already present
# 60 / 146
# File already present
# 61 / 146
# File already present
# 62 / 146
# File already present
# 63 / 146
# File already present
# 64 / 146
# File already present
# 65 / 146
# File already present
# 66 / 146
# File already present
# 67 / 146
# File already present
# 68 / 146
# File already present
# 69 / 146
# File already present
# 70 / 146
# File already present
# 71 / 146
# File already present
# 72 / 146
# File already present
# 73 / 146
# File already present
# 74 / 146
# File already present
# 75 / 146
# File already present
# 76 / 146
# File already present
# 77 / 146
# File already present
# 78 / 146
# File already present
# 79 / 146
# File already present
# 80 / 146
# File already present
# 81 / 146
# File already present
# 82 / 146
# File already present
# 83 / 146
# File already present
# 84 / 146
# File already present
# 85 / 146
# File already present
# 86 / 146
# File already present
# 87 / 146
# File already present
# 88 / 146
# File already present
# 89 / 146
# File already present
# 90 / 146
# File already present
# 91 / 146
# File already present
# 92 / 146
# File already present
# 93 / 146
# File already present
# 94 / 146
# File already present
# 95 / 146
# File already present
# 96 / 146
# File already present
# 97 / 146
# File already present
# 98 / 146
# File already present
# 99 / 146
# File already present
# 100 / 146
# File already present
# 101 / 146
# File already present
# 102 / 146
# File already present
# 103 / 146
# File already present
# 104 / 146
# File already present
# 105 / 146
# File already present
# 106 / 146
# File already present
# 107 / 146
# File already present
# 108 / 146
# File already present
# 109 / 146
# File already present
# 110 / 146
# File already present
# 111 / 146
# File already present
# 112 / 146
# File already present
# 113 / 146
# File already present
# 114 / 146
# File already present
# 115 / 146
# File already present
# 116 / 146
# File already present
# 117 / 146
# File already present
# 118 / 146
# File already present
# 119 / 146
# File already present
# 120 / 146
# File already present
# 121 / 146
# File already present
# 122 / 146
# File already present
# 123 / 146
# File already present
# 124 / 146
# File already present
# 125 / 146
# File already present
# 126 / 146
# File already present
# 127 / 146
# File already present
# 128 / 146
# File already present
# 129 / 146
# File already present
# 130 / 146
# File already present
# 131 / 146
# File already present
# 132 / 146
# File already present
# 133 / 146
# File already present
# 134 / 146
# File already present
# 135 / 146
# File already present
# 136 / 146
# File already present
# 137 / 146
# File already present
# 138 / 146
# File already present
# 139 / 146
# File already present
# 140 / 146
# File already present
# 141 / 146
# File already present
# 142 / 146
# File already present
# 143 / 146
# File already present
# 144 / 146
# File already present
# 145 / 146
# File already present
# 146 / 146
# File already present
# 147 / 146
# File already present
# 148 / 146
# File already present
# 149 / 146
# File already present
# 150 / 146
# File already present
# 151 / 146
# File already present
# 152 / 146
# File already present
# 153 / 146
# File already present
# 154 / 146
# File already present
# 155 / 146
# File already present
# 156 / 146
# File already present
# 157 / 146
# File already present
# 158 / 146
# File already present
# 159 / 146
# File already present
# 160 / 146
# File already present
# 161 / 146
# File already present
# 162 / 146
# File already present
# 163 / 146
# File already present
# 164 / 146
# File already present
# 165 / 146
# File already present
# 166 / 146
# File already present
# 167 / 146
# File already present
# 168 / 146
# File already present
# 169 / 146
# File already present
# 170 / 146
# File already present
# 171 / 146
# File already present
# 172 / 146
# File already present
# 173 / 146
# File already present
# 174 / 146
# File already present
# 175 / 146
# File already present
# 176 / 146
# File already present
# 177 / 146
# File already present
# 178 / 146
# File already present
# 179 / 146
# File already present
# 180 / 146
# File already present
# 181 / 146
# File already present
# 182 / 146
# File already present
# 183 / 146
# File already present
# 184 / 146
# File already present
# 185 / 146
# File already present
# 186 / 146
# File already present
# 187 / 146
# File already present
# 188 / 146
# File already present
# 189 / 146
# File already present
# 190 / 146
# File already present
# 191 / 146
# File already present
# 192 / 146
# File already present
# 193 / 146
# File already present
# 194 / 146
# File already present
# 195 / 146
# File already present
# 196 / 146
# File already present
# 197 / 146
# File already present
# 198 / 146
# File already present
# 199 / 146
# File already present
# 200 / 146
# File already present
# 201 / 146
# File already present
# 202 / 146
# File already present
# 203 / 146
# File already present
# 204 / 146
# File already present
# 205 / 146
# File already present
# 206 / 146
# File already present
# 207 / 146
# File already present
# 208 / 146
# File already present
# 209 / 146
# File already present
# 210 / 146
# File already present
# 211 / 146
# File already present
# 212 / 146
# File already present
# 213 / 146
# File already present
# 214 / 146
# File already present
# 215 / 146
# File already present
# 216 / 146
# File already present
# 217 / 146
# File already present
# 218 / 146
# File already present
# 219 / 146
# File already present
# 220 / 146
# File already present
# 221 / 146
# File already present
# 222 / 146
# File already present
# 223 / 146
# File already present
# 224 / 146
# File already present
# 225 / 146
# File already present
# 226 / 146
# File already present
# 227 / 146
# File already present
# 228 / 146
# File already present
# 229 / 146
# File already present
# 230 / 146
# File already present
# 231 / 146
# File already present
# 232 / 146
# File already present
# 233 / 146
# File already present
# 234 / 146
# File already present
# 235 / 146
# File already present
# 236 / 146
# File already present
# 237 / 146
# File already present
# 238 / 146
# File already present
# 239 / 146
# File already present
# 240 / 146
# File already present
# 241 / 146
# File already present
# 242 / 146
# File already present
# 243 / 146
# File already present
# 244 / 146
# File already present
# 245 / 146
# File already present
# 246 / 146
# File already present
# 247 / 146
# File already present
# 248 / 146
# File already present
# 249 / 146
# File already present
# 250 / 146
# File already present
# 251 / 146
# File already present
# 252 / 146
# File already present
# 253 / 146
# File already present
# 254 / 146
# File already present
# 255 / 146
# File already present
# 256 / 146
# File already present
# 257 / 146
# File already present
# 258 / 146
# File already present
# 259 / 146
# File already present
# 260 / 146
# File already present
# 261 / 146
# File already present
# 262 / 146
# File already present
# 263 / 146
# File already present
# 264 / 146
# File already present
# 265 / 146
# File already present
# 266 / 146
# File already present
# 267 / 146
# File already present
# 268 / 146
# File already present
# 269 / 146
# File already present
# 270 / 146
# File already present
# 271 / 146
# File already present
# 272 / 146
# File already present
# 273 / 146
# File already present
# 274 / 146
# File already present
# 275 / 146
# File already present
# 276 / 146
# File already present
# 277 / 146
# File already present
# 278 / 146
# File already present
# 279 / 146
# File already present
# 280 / 146
# File already present
# 281 / 146
# File already present
# 282 / 146
# File already present
# 283 / 146
# File already present
# 284 / 146
# File already present
# 285 / 146
# File already present
# 286 / 146
# File already present
# 287 / 146
# File already present
# 288 / 146
# File already present
# 289 / 146
# File already present
# 290 / 146
# File already present
# 291 / 146
# File already present
# 292 / 146
# File already present
# 293 / 146
# File already present
# 294 / 146
# File already present
# 295 / 146
# File already present
# 296 / 146
# File already present
# 297 / 146
# File already present
# 298 / 146
# File already present
# 299 / 146
# File already present
# 300 / 146
# File already present
# 301 / 146
# File already present
# 302 / 146
# File already present
# 303 / 146
# File already present
# 304 / 146
# File already present
# 305 / 146
# File already present
# 306 / 146
# File already present
# 307 / 146
# File already present
# 308 / 146
# File already present
# 309 / 146
# File already present
# 310 / 146
# File already present
# 311 / 146
# File already present
# 312 / 146
# File already present
# 313 / 146
# File already present
# 314 / 146
# File already present
# 315 / 146
# File already present
# 316 / 146
# File already present
# 317 / 146
# File already present
# 318 / 146
# File already present
# 319 / 146
# File already present
# 320 / 146
# File already present
# 321 / 146
# File already present
# 322 / 146
# File already present
# 323 / 146
# File already present
# 324 / 146
# File already present
# 325 / 146
# File already present
# 326 / 146
# File already present
# 327 / 146
# File already present
# 328 / 146
# File already present
# 329 / 146
# File already present
# 330 / 146
# File already present
# 331 / 146
# File already present
# 332 / 146
# File already present
# 333 / 146
# File already present
# 334 / 146
# File already present
# 335 / 146
# File already present
# 336 / 146
# File already present
# 337 / 146
# File already present
# 338 / 146
# File already present
# 339 / 146
# File already present
# 340 / 146
# File already present
# 341 / 146
# File already present
# 342 / 146
# File already present
# 343 / 146
# File already present
# 344 / 146
# File already present
# 345 / 146
# File already present
# 346 / 146
# File already present
# 347 / 146
# File already present
# 348 / 146
# File already present
# 349 / 146
# File already present
# 350 / 146
# File already present
# 351 / 146
# File already present
# 352 / 146
# File already present
# 353 / 146
# File already present
# 354 / 146
# File already present
# 355 / 146
# File already present
# 356 / 146
# File already present
# 357 / 146
# File already present
# 358 / 146
# File already present
# 359 / 146
# File already present
# 360 / 146
# File already present
# 361 / 146
# File already present
# 362 / 146
# File already present
# 363 / 146
# File already present
# 364 / 146
# File already present
# 365 / 146
# File already present
# 366 / 146
# File already present
# 367 / 146
# File already present
# 368 / 146
# File already present
# 369 / 146
# File already present
# 370 / 146
# File already present
# 371 / 146
# File already present
# 372 / 146
# File already present
# 373 / 146
# File already present
# 374 / 146
# File already present
# 375 / 146
# File already present
# 376 / 146
# File already present
# 377 / 146
# File already present
# 378 / 146
# File already present
# 379 / 146
# File already present
# 380 / 146
# File already present
# 381 / 146
# File already present
# 382 / 146
# File already present
# 383 / 146
# File already present
# 384 / 146
# File already present
# 385 / 146
# File already present
# 386 / 146
# File already present
# 387 / 146
# File already present
# 388 / 146
# File already present
# 389 / 146
# File already present
# 390 / 146
# File already present
# 391 / 146
# File already present
# 392 / 146
# File already present
# 393 / 146
# File already present
# 394 / 146
# File already present
# 395 / 146
# File already present
# 396 / 146
# File already present
# 397 / 146
# File already present
# 398 / 146
# File already present
# 399 / 146
# File already present
# 400 / 146
# File already present
# 401 / 146
# File already present
# 402 / 146
# File already present
# 403 / 146
# File already present
# 404 / 146
# File already present
# 405 / 146
# File already present
# 406 / 146
# File already present
# 407 / 146
# File already present
# 408 / 146
# File already present
# 409 / 146
# File already present
# 410 / 146
# File already present
# 411 / 146
# File already present
# 412 / 146
# File already present
# 413 / 146
# File already present
# 414 / 146
# File already present
# 415 / 146
# File already present
# 416 / 146
# File already present
# 417 / 146
# File already present
# 418 / 146
# File already present
# 419 / 146
# File already present
# 420 / 146
# File already present
# 421 / 146
# File already present
# 422 / 146
# File already present
# 423 / 146
# File already present
# 424 / 146
# File already present
# 425 / 146
# File already present
# 426 / 146
# File already present
# 427 / 146
# File already present
# 428 / 146
# File already present
# 429 / 146
# File already present
# 430 / 146
# File already present
# 431 / 146
# File already present
# 432 / 146
# File already present
# 433 / 146
# File already present
# 434 / 146
# File already present
# 435 / 146
# File already present
# 436 / 146
# File already present
# 437 / 146
# File already present
# 438 / 146
# File already present
# 439 / 146
# File already present
# 440 / 146
# File already present
# 441 / 146
# File already present
# 442 / 146
# File already present
# 443 / 146
# File already present
# 444 / 146
# File already present
# 445 / 146
# File already present
# 446 / 146
# File already present
# 447 / 146
# File already present
# 448 / 146
# File already present
# 449 / 146
# File already present
# 450 / 146
# File already present
# 451 / 146
# File already present
# 452 / 146
# File already present
# 453 / 146
# File already present
# 454 / 146
# File already present
# 455 / 146
# File already present
# 456 / 146
# File already present
# 457 / 146
# File already present
# 458 / 146
# File already present
# 459 / 146
# File already present
# 460 / 146
# File already present
# 461 / 146
# File already present
# 462 / 146
# File already present
# 463 / 146
# File already present
# 464 / 146
# File already present
# 465 / 146
# File already present
# 466 / 146
# File already present
# 467 / 146
# File already present
# 468 / 146
# File already present
# 469 / 146
# File already present
# 470 / 146
# File already present
# 471 / 146
# File already present
# 472 / 146
# File already present
# 473 / 146
# File already present
# 474 / 146
# File already present
# 475 / 146
# File already present
# 476 / 146
# File already present
# 477 / 146
# File already present
# 478 / 146
# File already present
# 479 / 146
# File already present
# 480 / 146
# File already present
# 481 / 146
# File already present
# 482 / 146
# File already present
# 483 / 146
# File already present
# 484 / 146
# File already present
# 485 / 146
# File already present
# 486 / 146
# File already present
# 487 / 146
# File already present
# 488 / 146
# File already present
# 489 / 146
# File already present
# 490 / 146
# File already present
# 491 / 146
# File already present
# 492 / 146
# File already present
# 493 / 146
# File already present
# 494 / 146
# File already present
# 495 / 146
# File already present
# 496 / 146
# File already present
# 497 / 146
# File already present
# 498 / 146
# File already present
# 499 / 146
# File already present
# 500 / 146
# File already present
# 501 / 146
# File already present
# 502 / 146
# File already present
# 503 / 146
# File already present
# 504 / 146
# File already present
# 505 / 146
# File already present
# 506 / 146
# File already present
# 507 / 146
# File already present
# 508 / 146
# File already present
# 509 / 146
# File already present
# 510 / 146
# File already present
# 511 / 146
# File already present
# 512 / 146
# File already present
# 513 / 146
# File already present
# 514 / 146
# File already present
# 515 / 146
# File already present
# 516 / 146
# File already present
# 517 / 146
# File already present
# 518 / 146
# File already present
# 519 / 146
# File already present
# 520 / 146
# File already present
# 521 / 146
# File already present
# 522 / 146
# File already present
# 523 / 146
# File already present
# 524 / 146
# File already present
# 525 / 146
# File already present
# 526 / 146
# File already present
# 527 / 146
# File already present
# 528 / 146
# File already present
# 529 / 146
# File already present
# 530 / 146
# File already present
# 531 / 146
# File already present
# 532 / 146
# File already present
# 533 / 146
# File already present
# 534 / 146
# File already present
# 535 / 146
# File already present
# 536 / 146
# File already present
# 537 / 146
# File already present
# 538 / 146
# File already present
# 539 / 146
# File already present
# 540 / 146
# File already present
# 541 / 146
# File already present
# 542 / 146
# File already present
# 543 / 146
# File already present
# 544 / 146
# File already present
# 545 / 146
# File already present
# 546 / 146
# File already present
# 547 / 146
# File already present
# 548 / 146
# File already present
# 549 / 146
# File already present
# 550 / 146
# File already present
# 551 / 146
# File already present
# 552 / 146
# File already present
# 553 / 146
# File already present
# 554 / 146
# File already present
# 555 / 146
# File already present
# 556 / 146
# File already present
# 557 / 146
# File already present
# 558 / 146
# File already present
# 559 / 146
# File already present
# 560 / 146
# File already present
# 561 / 146
# File already present
# 562 / 146
# File already present
# 563 / 146
# File already present
# 564 / 146
# File already present
# 565 / 146
# File already present
# 566 / 146
# File already present
# 567 / 146
# File already present
# 568 / 146
# File already present
# 569 / 146
# File already present
# 570 / 146
# File already present
# 571 / 146
# File already present
# 572 / 146
# File already present
# 573 / 146
# File already present
# 574 / 146
# File already present
# 575 / 146
# File already present
# 576 / 146
# File already present
# 577 / 146
# File already present
# 578 / 146
# File already present
# 579 / 146
# File already present
# 580 / 146
# File already present
# 581 / 146
# File already present
# 582 / 146
# File already present
# 583 / 146
# File already present
# 584 / 146
# File already present
# 585 / 146
# File already present
# 586 / 146
# File already present
# 587 / 146
# File already present
# 588 / 146
# File already present
# 589 / 146
# File already present
# 590 / 146
# File already present
# 591 / 146
# File already present
# 592 / 146
# File already present
# 593 / 146
# File already present
# 594 / 146
# File already present
# 595 / 146
# File already present
# 596 / 146
# File already present
# 597 / 146
# File already present
# 598 / 146
# File already present
# 599 / 146
# File already present
# 600 / 146
# File already present
# 601 / 146
# File already present
# 602 / 146
# File already present
# 603 / 146
# File already present
# 604 / 146
# File already present
# 605 / 146
# File already present
# 606 / 146
# File already present
# 607 / 146
# File already present
# 608 / 146
# File already present
# 609 / 146
# File already present
# 610 / 146
# File already present
# 611 / 146
# File already present
# 612 / 146
# File already present
# 613 / 146
# File already present
# 614 / 146
# File already present
# 615 / 146
# File already present
# 616 / 146
# File already present
# 617 / 146
# File already present
# 618 / 146
# File already present
# 619 / 146
# File already present
# 620 / 146
# File already present
# 621 / 146
# File already present
# 622 / 146
# File already present
# 623 / 146
# File already present
# 624 / 146
# File already present
# 625 / 146
# File already present
# 626 / 146
# File already present
# 627 / 146
# File already present
# 628 / 146
# File already present
# 629 / 146
# File already present
# 630 / 146
# File already present
# 631 / 146
# File already present
# 632 / 146
# File already present
# 633 / 146
# File already present
# 634 / 146
# File already present
# 635 / 146
# File already present
# 636 / 146
# File already present
# 637 / 146
# File already present
# 638 / 146
# File already present
# 639 / 146
# File already present
# 640 / 146
# File already present
# 641 / 146
# File already present
# 642 / 146
# File already present
# 643 / 146
# File already present
# 644 / 146
# File already present
# 645 / 146
# File already present
# 646 / 146
# File already present
# 647 / 146
# File already present
# 648 / 146
# File already present
# 649 / 146
# File already present
# 650 / 146
# File already present
# 651 / 146
# File already present
# 652 / 146
# File already present
# 653 / 146
# File already present
# 654 / 146
# File already present
# 655 / 146
# File already present
# 656 / 146
# File already present
# 657 / 146
# File already present
# 658 / 146
# File already present
# 659 / 146
# File already present
# 660 / 146
# File already present
# 661 / 146
# File already present
# 662 / 146
# File already present
# 663 / 146
# File already present
# 664 / 146
# File already present
# 665 / 146
# File already present
# 666 / 146
# File already present
# 667 / 146
# File already present
# 668 / 146
# File already present
# 669 / 146
# File already present
# 670 / 146
# File already present
# 671 / 146
# File already present
# 672 / 146
# File already present
# 673 / 146
# File already present
# 674 / 146
# File already present
# 675 / 146
# File already present
# 676 / 146
# File already present
# 677 / 146
# File already present
# 678 / 146
# File already present
# 679 / 146
# File already present
# 680 / 146
# File already present
# 681 / 146
# File already present
# 682 / 146
# File already present
# 683 / 146
# File already present
# 684 / 146
# File already present
# 685 / 146
# File already present
# 686 / 146
# File already present
# 687 / 146
# File already present
# 688 / 146
# File already present
# 689 / 146
# File already present
# 690 / 146
# File already present
# 691 / 146
# File already present
# 692 / 146
# File already present
# 693 / 146
# File already present
# 694 / 146
# File already present
# 695 / 146
# File already present
# 696 / 146
# File already present
# 697 / 146
# File already present
# 698 / 146
# File already present
# 699 / 146
# File already present
# 700 / 146
# File already present
# 701 / 146
# File already present
# 702 / 146
# File already present
# 703 / 146
# File already present
# 704 / 146
# File already present
# 705 / 146
# File already present
# 706 / 146
# File already present
# 707 / 146
# File already present
# 708 / 146
# File already present
# 709 / 146
# File already present
# 710 / 146
# File already present
# 711 / 146
# File already present
# 712 / 146
# File already present
# 713 / 146
# File already present
# 714 / 146
# File already present
# 715 / 146
# File already present
# 716 / 146
# File already present
# 717 / 146
# File already present
# 718 / 146
# File already present
# 719 / 146
# File already present
# 720 / 146
# File already present
# 721 / 146
# File already present
# 722 / 146
# File already present
# 723 / 146
# File already present
# 724 / 146
# File already present
# 725 / 146
# File already present
# 726 / 146
# File already present
# 727 / 146
# File already present
# 728 / 146
# File already present
# 729 / 146
# File already present
# 730 / 146
# File already present
# 731 / 146
# File already present
# 732 / 146
# File already present
# 733 / 146
# File already present
# 734 / 146
# File already present
# 735 / 146
# File already present
# 736 / 146
# File already present
# 737 / 146
# File already present
# 738 / 146
# File already present
# 739 / 146
# File already present
# 740 / 146
# File already present
# 741 / 146
# File already present
# 742 / 146
# File already present
# 743 / 146
# File already present
# 744 / 146
# File already present
# 745 / 146
# File already present
# 746 / 146
# File already present
# 747 / 146
# File already present
# 748 / 146
# File already present
# 749 / 146
# File already present
# 750 / 146
# File already present
# 751 / 146
# File already present
# 752 / 146
# File already present
# 753 / 146
# File already present
# 754 / 146
# File already present
# 755 / 146
# File already present
# 756 / 146
# File already present
# 757 / 146
# File already present
# 758 / 146
# File already present
# 759 / 146
# File already present
# 760 / 146
# File already present
# 761 / 146
# File already present
# 762 / 146
# File already present
# 763 / 146
# File already present
# 764 / 146
# File already present
# 765 / 146
# File already present
# 766 / 146
# File already present
# 767 / 146
# File already present
# 768 / 146
# File already present
# 769 / 146
# File already present
# 770 / 146
# File already present
# 771 / 146
# File already present
# 772 / 146
# File already present
# 773 / 146
# File already present
# 774 / 146
# File already present
# 775 / 146
# File already present
# 776 / 146
# File already present
# 777 / 146
# File already present
# 778 / 146
# File already present
# 779 / 146
# File already present
# 780 / 146
# File already present
# 781 / 146
# File already present
# 782 / 146
# File already present
# 783 / 146
# File already present
# 784 / 146
# File already present
# 785 / 146
# File already present
# 786 / 146
# File already present
# 787 / 146
# File already present
# 788 / 146
# File already present
# 789 / 146
# File already present
# 790 / 146
# File already present
# 791 / 146
# File already present
# 792 / 146
# File already present
# 793 / 146
# File already present
# 794 / 146
# File already present
# 795 / 146
# File already present
# 796 / 146
# File already present
# 797 / 146
# File already present
# 798 / 146
# File already present
# 799 / 146
# File already present
# 800 / 146
# File already present
# 801 / 146
# File already present
# 802 / 146
# File already present
# 803 / 146
# File already present
# 804 / 146
# File already present
# 805 / 146
# File already present
# 806 / 146
# File already present
# 807 / 146
# File already present
# 808 / 146
# File already present
# 809 / 146
# File already present
# 810 / 146
# File already present
# 811 / 146
# File already present
# 812 / 146
# File already present
# 813 / 146
# File already present
# 814 / 146
# File already present
# 815 / 146
# File already present
# 816 / 146
# File already present
# 817 / 146
# File already present
# 818 / 146
# File already present
# 819 / 146
# File already present
# 820 / 146
# File already present
# 821 / 146
# File already present
# 822 / 146
# File already present
# 823 / 146
# File already present
# 824 / 146
# File already present
# 825 / 146
# File already present
# 826 / 146
# File already present
# 827 / 146
# File already present
# 828 / 146
# File already present
# 829 / 146
# File already present
# 830 / 146
# File already present
# 831 / 146
# File already present
# 832 / 146
# File already present
# 833 / 146
# File already present
# 834 / 146
# File already present
# 835 / 146
# File already present
# 836 / 146
# File already present
# 837 / 146
# File already present
# 838 / 146
# File already present
# 839 / 146
# File already present
# 840 / 146
# File already present
# 841 / 146
# File already present
# 842 / 146
# File already present
# 843 / 146
# File already present
# 844 / 146
# File already present
# 845 / 146
# File already present
# 846 / 146
# File already present
# 847 / 146
# File already present
# 848 / 146
# File already present
# 849 / 146
# File already present
# 850 / 146
# File already present
# 851 / 146
# File already present
# 852 / 146
# File already present
# 853 / 146
# File already present
# 854 / 146
# File already present
# 855 / 146
# File already present
# 856 / 146
# File already present
# 857 / 146
# File already present
# 858 / 146
# File already present
# 859 / 146
# File already present
# 860 / 146
# File already present
# 861 / 146
# File already present
# 862 / 146
# File already present
# 863 / 146
# File already present
# 864 / 146
# File already present
# 865 / 146
# File already present
# 866 / 146
# File already present
# 867 / 146
# File already present
# 868 / 146
# File already present
# 869 / 146
# File already present
# 870 / 146
# File already present
# 871 / 146
# File already present
# 872 / 146
# File already present
# 873 / 146
# File already present
# 874 / 146
# File already present
# 875 / 146
# File already present
# 876 / 146
# File already present
# 877 / 146
# File already present
# 878 / 146
# File already present
# 879 / 146
# File already present
# 880 / 146
# File already present
# 881 / 146
# File already present
# 882 / 146
# File already present
# 883 / 146
# File already present
# 884 / 146
# File already present
# 885 / 146
# File already present
# 886 / 146
# File already present
# 887 / 146
# File already present
# 888 / 146
# File already present
# 889 / 146
# File already present
# 890 / 146
# File already present
# 891 / 146
# File already present
# 892 / 146
# File already present
# 893 / 146
# File already present
# 894 / 146
# File already present
# 895 / 146
# File already present
# 896 / 146
# File already present
# 897 / 146
# File already present
# 898 / 146
# File already present
# 899 / 146
# File already present
# 900 / 146
# File already present
# 901 / 146
# File already present
# 902 / 146
# File already present
# 903 / 146
# File already present
# 904 / 146
# File already present
# 905 / 146
# File already present
# 906 / 146
# File already present
# 907 / 146
# File already present
# 908 / 146
# File already present
# 909 / 146
# File already present
# 910 / 146
# File already present
# 911 / 146
# File already present
# 912 / 146
# File already present
# 913 / 146
# File already present
# 914 / 146
# File already present
# 915 / 146
# File already present
# 916 / 146
# File already present
# 917 / 146
# File already present
# 918 / 146
# File already present
# 919 / 146
# File already present
# 920 / 146
# File already present
# 921 / 146
# File already present
# 922 / 146
# File already present
# 923 / 146
# File already present
# 924 / 146
# File already present
# 925 / 146
# File already present
# 926 / 146
# File already present
# 927 / 146
# File already present
# 928 / 146
# File already present
# 929 / 146
# File already present
# 930 / 146
# File already present
# 931 / 146
# File already present
# 932 / 146
# File already present
# 933 / 146
# File already present
# 934 / 146
# File already present
# 935 / 146
# File already present
# 936 / 146
# File already present
# 937 / 146
# File already present
# 938 / 146
# File already present
# 939 / 146
# File already present
# 940 / 146
# File already present
# 941 / 146
# File already present
# 942 / 146
# File already present
# 943 / 146
# File already present
# 944 / 146
# File already present
# 945 / 146
# File already present
# 946 / 146
# File already present
# 947 / 146
# File already present
# 948 / 146
# File already present
# 949 / 146
# File already present
# 950 / 146
# File already present
# 951 / 146
# File already present
# 952 / 146
# File already present
# 953 / 146
# File already present
# 954 / 146
# File already present
# 955 / 146
# File already present
# 956 / 146
# File already present
# 957 / 146
# File already present
# 958 / 146
# File already present
# 959 / 146
# File already present
# 960 / 146
# File already present
# 961 / 146
# File already present
# 962 / 146
# File already present
# 963 / 146
# File already present
# 964 / 146
# File already present
# 965 / 146
# File already present
# 966 / 146
# File already present
# 967 / 146
# File already present
# 968 / 146
# File already present
# 969 / 146
# File already present
# 970 / 146
# File already present
# 971 / 146
# File already present
# 972 / 146
# File already present
# 973 / 146
# File already present
# 974 / 146
# File already present
# 975 / 146
# File already present
# 976 / 146
# File already present
# 977 / 146
# File already present
# 978 / 146
# File already present
# 979 / 146
# File already present
# 980 / 146
# File already present
# 981 / 146
# File already present
# 982 / 146
# File already present
# 983 / 146
# File already present
# 984 / 146
# File already present
# 985 / 146
# File already present
# 986 / 146
# File already present
# 987 / 146
# File already present
# 988 / 146
# File already present
# 989 / 146
# File already present
# 990 / 146
# File already present
# 991 / 146
# File already present
# 992 / 146
# File already present
# 993 / 146
# File already present
# 994 / 146
# File already present
# 995 / 146
# File already present
# 996 / 146
# File already present
# 997 / 146
# File already present
# 998 / 146
# File already present
# 999 / 146
# File already present
# 1000 / 146
# File already present
# 1001 / 146
# File already present
# 1002 / 146
# File already present
# 1003 / 146
# File already present
# 1004 / 146
# File already present
# 1005 / 146
# File already present
# 1006 / 146
# File already present
# 1007 / 146
# File already present
# 1008 / 146
# File already present
# 1009 / 146
# File already present
# 1010 / 146
# File already present
# 1011 / 146
# File already present
# 1012 / 146
# File already present
# 1013 / 146
# File already present
# 1014 / 146
# File already present
# 1015 / 146
# File already present
# 1016 / 146
# File already present
# 1017 / 146
# File already present
# 1018 / 146
# File already present
# 1019 / 146
# File already present
# 1020 / 146
# File already present
# 1021 / 146
# File already present
# 1022 / 146
# File already present
# 1023 / 146
# File already present
# 1024 / 146
# File already present
# 1025 / 146
# File already present
# 1026 / 146
# File already present
# 1027 / 146
# File already present
# 1028 / 146
# File already present
# 1029 / 146
# File already present
# 1030 / 146
# File already present
# 1031 / 146
# File already present
# 1032 / 146
# File already present
# 1033 / 146
# File already present
# 1034 / 146
# File already present
# 1035 / 146
# File already present
# 1036 / 146
# File already present
# 1037 / 146
# File already present
# 1038 / 146
# File already present
# 1039 / 146
# File already present
# 1040 / 146
# File already present
# 1041 / 146
# File already present
# 1042 / 146
# File already present
# 1043 / 146
# File already present
# 1044 / 146
# File already present
# 1045 / 146
# File already present
# 1046 / 146
# File already present
# 1047 / 146
# File already present
# 1048 / 146
# File already present
# 1049 / 146
# File already present
# 1050 / 146
# File already present
# 1051 / 146
# File already present
# 1052 / 146
# File already present
# 1053 / 146
# File already present
# 1054 / 146
# File already present
# 1055 / 146
# File already present
# 1056 / 146
# File already present
# 1057 / 146
# File already present
# 1058 / 146
# File already present
# 1059 / 146
# File already present
# 1060 / 146
# File already present
# 1061 / 146
# File already present
# 1062 / 146
# File already present
# 1063 / 146
# File already present
# 1064 / 146
# File already present
# 1065 / 146
# File already present
# 1066 / 146
# File already present
# 1067 / 146
# File already present
# 1068 / 146
# File already present
# 1069 / 146
# File already present
# 1070 / 146
# File already present
# 1071 / 146
# File already present
# 1072 / 146
# File already present
# 1073 / 146
# File already present
# 1074 / 146
# File already present
# 1075 / 146
# File already present
# 1076 / 146
# File already present
# 1077 / 146
# File already present
# 1078 / 146
# File already present
# 1079 / 146
# File already present
# 1080 / 146
# File already present
# 1081 / 146
# File already present
# 1082 / 146
# File already present
# 1083 / 146
# File already present
# 1084 / 146
# File already present
# 1085 / 146
# File already present
# 1086 / 146
# File already present
# 1087 / 146
# File already present
# 1088 / 146
# File already present
# 1089 / 146
# File already present
# 1090 / 146
# File already present
# 1091 / 146
# File already present
# 1092 / 146
# File already present
# 1093 / 146
# File already present
# 1094 / 146
# File already present
# 1095 / 146
# File already present
# 1096 / 146
# File already present
# 1097 / 146
# File already present
# 1098 / 146
# File already present
# 1099 / 146
# File already present
# 1100 / 146
# File already present
# 1101 / 146
# File already present
# 1102 / 146
# File already present
# 1103 / 146
# File already present
# 1104 / 146
# File already present
# 1105 / 146
# File already present
# 1106 / 146
# File already present
# 1107 / 146
# File already present
# 1108 / 146
# File already present
# 1109 / 146
# File already present
# 1110 / 146
# File already present
# 1111 / 146
# File already present
# 1112 / 146
# File already present
# 1113 / 146
# File already present
# 1114 / 146
# File already present
# 1115 / 146
# File already present
# 1116 / 146
# File already present
# 1117 / 146
# File already present
# 1118 / 146
# File already present
# 1119 / 146
# File already present
# 1120 / 146
# File already present
# 1121 / 146
# File already present
# 1122 / 146
# File already present
# 1123 / 146
# File already present
# 1124 / 146
# File already present
# 1125 / 146
# File already present
# 1126 / 146
# File already present
# 1127 / 146
# File already present
# 1128 / 146
# File already present
# 1129 / 146
# File already present
# 1130 / 146
# File already present
# 1131 / 146
# File already present
# 1132 / 146
# File already present
# 1133 / 146
# File already present
# 1134 / 146
# File already present
# 1135 / 146
# File already present
# 1136 / 146
# File already present
# 1137 / 146
# File already present
# 1138 / 146
# File already present
# 1139 / 146
# File already present
# 1140 / 146
# File already present
# 1141 / 146
# File already present
# 1142 / 146
# File already present
# 1143 / 146
# File already present
# 1144 / 146
# File already present
# 1145 / 146
# File already present
# 1146 / 146
# File already present
# 1147 / 146
# File already present
# 1148 / 146
# File already present
# 1149 / 146
# File already present
# 1150 / 146
# File already present
# 1151 / 146
# File already present
# 1152 / 146
# File already present
# 1153 / 146
# File already present
# 1154 / 146
# File already present
# 1155 / 146
# File already present
# 1156 / 146
# File already present
# 1157 / 146
# File already present
# 1158 / 146
# File already present
# 1159 / 146
# File already present
# 1160 / 146
# File already present
# 1161 / 146
# File already present
# 1162 / 146
# File already present
# 1163 / 146
# File already present
# 1164 / 146
# File already present
# 1165 / 146
# File already present
# 1166 / 146
# File already present
# 1167 / 146
# File already present
# 1168 / 146
# File already present
# 1169 / 146
# File already present
# 1170 / 146
# File already present
# 1171 / 146
# File already present
# 1172 / 146
# File already present
# 1173 / 146
# File already present
# 1174 / 146
# File already present
# 1175 / 146
# File already present
# 1176 / 146
# File already present

# %% [markdown]
# ### Converting the DICOM images to PNG

# %%
# Rescale the intensity of the image to get heterogene images with the bit depth of 14
def rescale_to_8bit(image_array):
    upper_percentile = np.percentile(image_array.flatten(), 98) # original_max = np.max(image_array)
    lower_percentile = np.percentile(image_array.flatten(), 2) # original_min = np.min(image_array)
    # max_on_14bit = 16383
    max = 255
    rescaled_array = (image_array - lower_percentile) / (upper_percentile - lower_percentile)
    rescaled_array[rescaled_array < 0] = 0
    rescaled_array[rescaled_array > 1] = 1
    # rescaled_array = np.round((image_array - original_min) / (original_max - original_min) * max_on_14bit).astype(int)
    return np.round(rescaled_array * 255).astype(np.uint8)

def generate_png_path(dcm_path):
    # Get new file name
    split_fn = dcm_path[:-4].split('/')
    new_fn = f"{split_fn[-1]}_conv.png"
    return image_path + new_fn

# Save DICOM pixel array as PNG
def save_dcm_image_as_png(image, png_filename, bitdepth=8):
    with open(png_filename, 'wb') as f:
        rescaled = rescale_to_8bit(image)
        writer = png.Writer(height=rescaled.shape[0], 
                            width=rescaled.shape[1], 
                            bitdepth=bitdepth, 
                            greyscale=True)
        writer.write(f, rescaled.tolist())

def generate_png_path(acc_anon, png_dir):
    # Get new file name
    new_fn = f"{acc_anon}_pos_conv.png"
    return f'{png_dir}/{new_fn}'

# Convert list of DICOMs to PNGs
def process_dcm_list(dcm_list, png_list):    
    for i, dcm_path in enumerate(dcm_list):    
        if not Path(png_list[i]).exists():
            print(f"Processing DICOM #{i}...")
            
            # Load DICOM
            dcm = pydicom.dcmread(dcm_path)
            img = dcm.pixel_array
            
            # Save PNG            
            save_dcm_image_as_png(img, png_list[i])

def extract_images(data_file_name, dcm_dir, png_dir):
    # Provide a list of DICOM paths and a target directory
    dcm_list = []
    df = pd.read_csv(data_file_name)
    
    for index, row in df.iterrows():
        path = dcm_dir  + row['relative_dcm_path']
        if Path(path).exists():
            dcm_list.append(path)
        
    # Insert png path
    df.loc[:,'png_path'] = df['acc_anon'].apply(lambda x: generate_png_path(x, png_dir))

    # Convert DICOMs
    process_dcm_list(dcm_list, df['png_path'])

    return df

# %%
pos_img_emp = extract_images(data_path + 'positive_empirical.csv', image_dcm_path, image_png_path)

with open(data_path + 'positive_empirical_png.csv', 'w') as f:
    (pos_img_emp).to_csv(f, index=False)
# Out:
# Processing DICOM #0...
# Processing DICOM #2...
# Processing DICOM #4...
# Processing DICOM #6...
# Processing DICOM #9...
# Processing DICOM #13...
# Processing DICOM #15...
# Processing DICOM #17...
# Processing DICOM #19...
# Processing DICOM #23...
# Processing DICOM #25...
# Processing DICOM #27...
# Processing DICOM #32...
# Processing DICOM #34...
# Processing DICOM #38...
# Processing DICOM #42...
# Processing DICOM #45...
# Processing DICOM #48...
# Processing DICOM #52...
# Processing DICOM #54...
# Processing DICOM #56...
# Processing DICOM #60...
# Processing DICOM #62...
# Processing DICOM #64...
# Processing DICOM #66...
# Processing DICOM #68...
# Processing DICOM #70...
# Processing DICOM #72...
# Processing DICOM #74...
# Processing DICOM #78...
# Processing DICOM #80...
# Processing DICOM #84...
# Processing DICOM #86...
# Processing DICOM #88...
# Processing DICOM #94...
# Processing DICOM #98...
# Processing DICOM #99...
# Processing DICOM #103...
# Processing DICOM #105...
# Processing DICOM #107...
# Processing DICOM #108...
# Processing DICOM #110...
# Processing DICOM #112...
# Processing DICOM #114...
# Processing DICOM #116...
# Processing DICOM #118...
# Processing DICOM #119...
# Processing DICOM #121...
# Processing DICOM #126...
# Processing DICOM #128...
# Processing DICOM #130...
# Processing DICOM #132...
# Processing DICOM #134...
# Processing DICOM #137...
# Processing DICOM #139...
# Processing DICOM #141...
# Processing DICOM #143...
# Processing DICOM #145...
# Processing DICOM #147...
# Processing DICOM #149...
# Processing DICOM #151...
# Processing DICOM #153...
# Processing DICOM #154...
# Processing DICOM #158...
# Processing DICOM #164...
# Processing DICOM #166...
# Processing DICOM #170...
# Processing DICOM #174...
# Processing DICOM #175...
# Processing DICOM #177...
# Processing DICOM #179...
# Processing DICOM #181...
# Processing DICOM #185...
# Processing DICOM #187...
# Processing DICOM #189...
# Processing DICOM #191...
# Processing DICOM #193...
# Processing DICOM #194...
# Processing DICOM #196...
# Processing DICOM #198...
# Processing DICOM #200...
# Processing DICOM #202...
# Processing DICOM #203...
# Processing DICOM #206...
# Processing DICOM #209...
# Processing DICOM #211...
# Processing DICOM #213...
# Processing DICOM #215...
# Processing DICOM #217...
# Processing DICOM #219...
# Processing DICOM #220...
# Processing DICOM #223...
# Processing DICOM #225...
# Processing DICOM #227...
# Processing DICOM #229...
# Processing DICOM #232...
# Processing DICOM #234...
# Processing DICOM #236...
# Processing DICOM #240...
# Processing DICOM #243...
# Processing DICOM #245...
# Processing DICOM #247...
# Processing DICOM #249...
# Processing DICOM #251...
# Processing DICOM #255...
# Processing DICOM #259...
# Processing DICOM #261...
# Processing DICOM #265...
# Processing DICOM #267...
# Processing DICOM #269...
# Processing DICOM #271...
# Processing DICOM #273...
# Processing DICOM #274...
# Processing DICOM #276...
# Processing DICOM #278...
# Processing DICOM #280...
# Processing DICOM #282...
# Processing DICOM #284...
# Processing DICOM #286...
# Processing DICOM #287...
# Processing DICOM #289...
# Processing DICOM #296...
# Processing DICOM #298...
# Processing DICOM #300...
# Processing DICOM #301...
# Processing DICOM #303...
# Processing DICOM #305...
# Processing DICOM #307...
# Processing DICOM #309...
# Processing DICOM #311...
# Processing DICOM #313...
# Processing DICOM #317...
# Processing DICOM #319...
# Processing DICOM #321...
# Processing DICOM #323...
# Processing DICOM #325...
# Processing DICOM #328...
# Processing DICOM #332...
# Processing DICOM #334...
# Processing DICOM #336...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11835/2860042586.py in ?()
# ----> 1 pos_img_emp = extract_images(data_path + 'positive_empirical.csv', image_dcm_path, image_png_path)
#       2
#       3 with open(data_path + 'positive_empirical_png.csv', 'w') as f:
#       4     (pos_img_emp).to_csv(f, index=False)
#
# /tmp/ipykernel_11835/2139131369.py in ?(data_file_name, dcm_dir, png_dir)
#      57     # Insert png path
#      58     df.loc[:,'png_path'] = df['acc_anon'].apply(lambda x: generate_png_path(x, png_dir))
#      59
#      60     # Convert DICOMs
# ---> 61     process_dcm_list(dcm_list, df['png_path'])
#      62
#      63     return df
#
# /tmp/ipykernel_11835/2139131369.py in ?(dcm_list, png_list)
#      38             print(f"Processing DICOM #{i}...")
#      39
#      40             # Load DICOM
#      41             dcm = pydicom.dcmread(dcm_path)
# ---> 42             img = dcm.pixel_array
#      43
#      44             # Save PNG
#      45             save_dcm_image_as_png(img, png_list[i])
#
# ~/.local/lib/python3.10/site-packages/pydicom/dataset.py in ?(self)
#    1951             The (7FE0,0008) *Float Pixel Data*, (7FE0,0009) *Double Float
#    1952             Pixel Data* or (7FE0,0010) *Pixel Data* converted to a
#    1953             :class:`numpy.ndarray`.
#    1954         """
# -> 1955         self.convert_pixel_data()
#    1956         return cast("numpy.ndarray", self._pixel_array)
#
# ~/.local/lib/python3.10/site-packages/pydicom/dataset.py in ?(self, handler_name)
#    1508
#    1509         if handler_name:
#    1510             self._convert_pixel_data_using_handler(handler_name)
#    1511         else:
# -> 1512             self._convert_pixel_data_without_handler()
#
# ~/.local/lib/python3.10/site-packages/pydicom/dataset.py in ?(self)
#    1602         for handler in available_handlers:
#    1603             try:
#    1604                 self._do_pixel_data_conversion(handler)
#    1605                 return
# -> 1606             except Exception as exc:
#    1607                 logger.debug(
#    1608                     "Exception raised by pixel data handler", exc_info=exc
#    1609                 )
#
# ~/.local/lib/python3.10/site-packages/pydicom/dataset.py in ?(self, handler)
#    1627         """Do the actual data conversion using the given handler."""
#    1628
#    1629         # Use the handler to get a 1D numpy array of the pixel data
#    1630         # Will raise an exception if no pixel data element
# -> 1631         arr = handler.get_pixeldata(self)
#    1632         self._pixel_array = reshape_pixel_array(self, arr)
#    1633
#    1634         # Some handler/transfer syntax combinations may need to
#
# ~/.local/lib/python3.10/site-packages/pydicom/pixel_data_handlers/gdcm_handler.py in ?(ds)
#     243
#     244     if HAVE_GDCM_IN_MEMORY_SUPPORT:
#     245         gdcm_data_element = create_data_element(ds)
#     246         gdcm_image = create_image(ds, gdcm_data_element)
# --> 247         pixel_str = gdcm_image.GetBuffer()
#     248     else:
#     249         pixel_str = _get_pixel_str_fileio(ds)
#     250
#
# ~/.local/lib/python3.10/site-packages/_gdcm/gdcmswig.py in ?(self)
#    4889         gdcm::Bitmap::GetBuffer(char *buffer) const
#    4890
#    4891         Access the raw data.
#    4892         """
# -> 4893         return _gdcmswig.Bitmap_GetBuffer(self)
#
# KeyboardInterrupt:
